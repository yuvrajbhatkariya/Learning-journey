# %% [markdown]
# ## Saving model in file :-
#
# # 1. pickle :

# %%
import pickle

# %%
with open('tut5_pickel','rb') as f:
    mp = pickle.load(f)

# %%
y_pred = mp.predict([[1200,2,2]])
y_pred
# Out:
# /Users/yuvrajbhatkariya/data/VScode.C++/Python/myenv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([340283.74143238])

# %% [markdown]
# # 2. Joblib : -

# %%
import joblib

# %%
mj = joblib.load('tut5_joblib')

# %%
Y_pred = mj.predict([[1200,2,2]])
Y_pred
# Out:
# /Users/yuvrajbhatkariya/data/VScode.C++/Python/myenv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([340283.74143238])

# %%
print(mj.coef_[0])
print(mj.intercept_)
# Out:
# 231.19925217786735
# 4008.6930139570613
