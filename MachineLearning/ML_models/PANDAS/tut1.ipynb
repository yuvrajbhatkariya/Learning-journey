# %%
import pandas as pd
import numpy as np
print ('HELLO VEDNESDAY')
# Out:
# HELLO VEDNESDAY

# %%
A = np.arange(1,21).reshape(4,5)

# %%
#  creating a DataFrameWork :-

new = pd.DataFrame(data = A,index = ["Row1","Row2","Row3","Row4"],
             columns = ["Columns1","Columns2","Columns3","Columns4","Columns5"] )

# %%
new.head(3)
new.tail(3)
# Out:
#       Columns1  Columns2  Columns3  Columns4  Columns5
# Row2         6         7         8         9        10
# Row3        11        12        13        14        15
# Row4        16        17        18        19        20

# %%
type(new)
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Row1 to Row4
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Columns1  4 non-null      int32
#  1   Columns2  4 non-null      int32
#  2   Columns3  4 non-null      int32
#  3   Columns4  4 non-null      int32
#  4   Columns5  4 non-null      int32
# dtypes: int32(5)
# memory usage: 112.0+ bytes

# %%
new.describe()
# Out:
#         Columns1   Columns2   Columns3   Columns4   Columns5
# count   4.000000   4.000000   4.000000   4.000000   4.000000
# mean    8.500000   9.500000  10.500000  11.500000  12.500000
# std     6.454972   6.454972   6.454972   6.454972   6.454972
# min     1.000000   2.000000   3.000000   4.000000   5.000000
# 25%     4.750000   5.750000   6.750000   7.750000   8.750000
# 50%     8.500000   9.500000  10.500000  11.500000  12.500000
# 75%    12.250000  13.250000  14.250000  15.250000  16.250000
# max    16.000000  17.000000  18.000000  19.000000  20.000000

# %%
# INDEXING : -
#  1. by column name:
new['Columns1']                  # it is series type
new[['Columns2','Columns3']]     # is dataftame
# Out:
#       Columns2  Columns3
# Row1         2         3
# Row2         7         8
# Row3        12        13
# Row4        17        18

# %%
# 2. by row index: -
new.loc[['Row4','Row3']] 
new
# Out:
#       Columns1  Columns2  Columns3  Columns4  Columns5
# Row1         1         2         3         4         5
# Row2         6         7         8         9        10
# Row3        11        12        13        14        15
# Row4        16        17        18        19        20

# %%
# 3.by iloc
new.iloc[2:3,0:4]
# Out:
#       Columns1  Columns2  Columns3  Columns4
# Row3        11        12        13        14

# %%
# convert dataframe into array format
new.iloc[ : , 2:].values
# Out:
# array([[ 3,  4,  5],
#        [ 8,  9, 10],
#        [13, 14, 15],
#        [18, 19, 20]])

# %%
#  Creating a new data frame havinf nan value :-)
df = pd.DataFrame(data = [[1,np.nan,2],[1,2,3]],index = ["Row1","Row2"],
             columns = ["Columns1","Columns2","Columns3"] )
df
# Out:
#       Columns1  Columns2  Columns3
# Row1         1       NaN         2
# Row2         1       2.0         3

# %%
df.isnull()
# Out:
#       Columns1  Columns2  Columns3
# Row1     False      True     False
# Row2     False     False     False

# %%
df.isnull().sum()
# Out:
# Columns1    0
# Columns2    1
# Columns3    0
# dtype: int64

# %%
df
# Out:
#       Columns1  Columns2  Columns3
# Row1         1       NaN         2
# Row2         1       2.0         3

# %%
df['Columns3'].value_counts()
# Out:
# Columns3
# 2    1
# 3    1
# Name: count, dtype: int64

# %%
df['Columns3'].unique()
# Out:
# array([2, 3], dtype=int64)

# %%
new
# Out:
#       Columns1  Columns2  Columns3  Columns4  Columns5
# Row1         1         2         3         4         5
# Row2         6         7         8         9        10
# Row3        11        12        13        14        15
# Row4        16        17        18        19        20

# %%
new[new['Columns3']>3]
# Out:
#       Columns1  Columns2  Columns3  Columns4  Columns5
# Row2         6         7         8         9        10
# Row3        11        12        13        14        15
# Row4        16        17        18        19        20
