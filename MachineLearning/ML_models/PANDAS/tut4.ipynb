# %%
import pandas as pd

# %%
html = pd.read_html("https://en.wikipedia.org/wiki/Economy_of_India")

# %%
type(html)
# Out:
# list

# %%
html
# Out:
# [                                                    0  \
#  0         Mumbai, the financial centre of India[1][2]
#  1                                            Currency
#  2                                         Fiscal year
#  3                                 Trade organisations
#  4                                       Country group
#  5                                          Statistics
#  6                                          Population
#  7                                                 GDP
#  8                                            GDP rank
#  9                                          GDP growth
#  10                                     GDP per capita
#  11                                GDP per capita rank
#  12                                      GDP by sector
#  13                                   GDP by component
#  14                                    Inflation (CPI)
#  15                                Base borrowing rate
# ...

# %%
html[0]
# Out:
#                                                     0  \
# 0         Mumbai, the financial centre of India[1][2]
# 1                                            Currency
# 2                                         Fiscal year
# 3                                 Trade organisations
# 4                                       Country group
# 5                                          Statistics
# 6                                          Population
# 7                                                 GDP
# 8                                            GDP rank
# 9                                          GDP growth
# 10                                     GDP per capita
# 11                                GDP per capita rank
# 12                                      GDP by sector
# 13                                   GDP by component
# 14                                    Inflation (CPI)
# 15                                Base borrowing rate
# ...

# %%
html = pd.read_html("https://en.wikipedia.org/wiki/Economy_of_India",match = "Acquiror Nation")

# %%
html
# Out:
# [                                 0                            1  \
#  0                    Acquiror Name        Acquiror Mid Industry
#  1           Petrol Complex Pte Ltd                    Oil & Gas
#  2                 Vodafone Grp Plc                     Wireless
#  3   Vodafone Grp PLC-Vodafone Asts                     Wireless
#  4                Bharti Airtel Ltd                     Wireless
#  5                Bharti Airtel Ltd                     Wireless
#  6                           BP PLC                    Oil & Gas
#  7                    MTN Group Ltd                     Wireless
#  8                     Shareholders             Other Financials
#  9       Oil & Natural Gas Corp Ltd                    Oil & Gas
#  10    Reliance Commun Ventures Ltd  Telecommunications Services
#
#                    2                               3  \
#  0   Acquiror Nation                     Target Name
#  1         Singapore                   Essar Oil Ltd
# ...

# %%
html[0]
# Out:
#                                  0                            1  \
# 0                    Acquiror Name        Acquiror Mid Industry
# 1           Petrol Complex Pte Ltd                    Oil & Gas
# 2                 Vodafone Grp Plc                     Wireless
# 3   Vodafone Grp PLC-Vodafone Asts                     Wireless
# 4                Bharti Airtel Ltd                     Wireless
# 5                Bharti Airtel Ltd                     Wireless
# 6                           BP PLC                    Oil & Gas
# 7                    MTN Group Ltd                     Wireless
# 8                     Shareholders             Other Financials
# 9       Oil & Natural Gas Corp Ltd                    Oil & Gas
# 10    Reliance Commun Ventures Ltd  Telecommunications Services
#
#                   2                               3  \
# 0   Acquiror Nation                     Target Name
# 1         Singapore                   Essar Oil Ltd
# ...

# %%
html = pd.read_html("https://en.wikipedia.org/wiki/Economy_of_India")
A = html[2]

# %%
A.to_html('test.html')

# %%
df = pd.read_csv('test.csv')


df
# Out:
#          id        f0        f1         f2        f3        f4        f5  \
# 0     15000  0.398169  2.143300   114.8780  3.816510  0.089995  1.042540
# 1     15001  0.008505  2.349320   853.8810  5.231130  0.049947  1.107780
# 2     15002  2.767680  2.084530   148.9250  4.046420  0.007924  4.261860
# 3     15003  1.071190  5.919520   -64.0648  0.195529  0.079169  0.903287
# 4     15004  0.068140  3.539450   -25.8223  5.739260  0.038304  3.349190
# ...     ...       ...       ...        ...       ...       ...       ...
# 9995  24995 -0.005145  3.001410   210.6070  0.994924  0.019112  2.783550
# 9996  24996  0.119577  4.266310   162.3760  1.245620  0.026891  1.119720
# 9997  24997 -0.074183  0.268787   199.6410  5.217750 -0.036501  3.469370
# 9998  24998 -0.049194  4.064200  3400.6200  3.039560  0.089791  1.248200
# 9999  24999  0.024247  1.525240   140.1220  1.444970  0.110097  0.614881
#
#             f6        f7        f8  ...       f90       f91       f92  \
# ...

# %%
A = df.iloc[:6,:7]

# %%
A.to_html('test2.html')
