# %%
# from io import StringIO
import pandas as pd
import numpy as np

# %%
pd.read_csv('test.csv')
# Out:
#          id        f0        f1         f2        f3        f4        f5  \
# 0     15000  0.398169  2.143300   114.8780  3.816510  0.089995  1.042540
# 1     15001  0.008505  2.349320   853.8810  5.231130  0.049947  1.107780
# 2     15002  2.767680  2.084530   148.9250  4.046420  0.007924  4.261860
# 3     15003  1.071190  5.919520   -64.0648  0.195529  0.079169  0.903287
# 4     15004  0.068140  3.539450   -25.8223  5.739260  0.038304  3.349190
# ...     ...       ...       ...        ...       ...       ...       ...
# 9995  24995 -0.005145  3.001410   210.6070  0.994924  0.019112  2.783550
# 9996  24996  0.119577  4.266310   162.3760  1.245620  0.026891  1.119720
# 9997  24997 -0.074183  0.268787   199.6410  5.217750 -0.036501  3.469370
# 9998  24998 -0.049194  4.064200  3400.6200  3.039560  0.089791  1.248200
# 9999  24999  0.024247  1.525240   140.1220  1.444970  0.110097  0.614881
#
#             f6        f7        f8  ...       f90       f91       f92  \
# ...

# %%
# converting stirng into file format :-)

data = ('Columns1,Column2,columns\n'
    'a,B,1\n'
    'x,Y,2')
type(data)
# Out:
# str

# %%
from io import StringIO
StringIO(data)            # convrt string into file format :-

f = pd.read_csv(StringIO(data))
f
# Out:
#   Columns1 Column2  columns
# 0        a       B        1
# 1        x       Y        2

# %%
type(f)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv('test.csv',usecols = ['id'	,'f0',	'f1',	'f2',	'f3'	,'f4'	,'f5']	)
h = df.head()

# %%
h.to_csv('test1.csv')
# without index
h.to_csv('test2.csv',index = False)

# %%
data = ('Columns1,Column2,columns3,column4\n'
    'a,B,1,2\n'
    'x,Y,2')
A = pd.read_csv(StringIO(data))

# %%
pd.isnull(A).sum()
# Out:
# Columns1    0
# Column2     0
# columns3    0
# column4     1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10000 non-null  int64
#  1   f0      10000 non-null  float64
#  2   f1      10000 non-null  float64
#  3   f2      10000 non-null  float64
#  4   f3      10000 non-null  float64
#  5   f4      10000 non-null  float64
#  6   f5      10000 non-null  float64
# dtypes: float64(6), int64(1)
# memory usage: 547.0 KB

# %%
# change data type :-)
df = pd.read_csv(StringIO(data),dtype = 'object')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Columns1  2 non-null      object
#  1   Column2   2 non-null      object
#  2   columns3  2 non-null      object
#  3   column4   1 non-null      object
# dtypes: object(4)
# memory usage: 192.0+ bytes

# %%
A = pd.read_csv('test.csv')
A['f0'][2]
# Out:
# 2.76768

# %%
data = ('Columns1,Column2,columns3,column4\n'
    '1,2,3,4\n'
    '2,5,6')
A = pd.read_csv(StringIO(data))

# %%
# change data type :-)
df = pd.read_csv(StringIO(data),dtype = {'Columns1': int , 'Columns2': float,'columns':int})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Columns1  2 non-null      int32
#  1   Column2   2 non-null      int64
#  2   columns3  2 non-null      int64
#  3   column4   1 non-null      float64
# dtypes: float64(1), int32(1), int64(2)
# memory usage: 184.0 bytes

# %%
data = ('MyIndex,Columns1,Column2,columns3,column4\n'
    '11,tony,100,4,p\n'
    '22,vednesday,200,6\n'
    '33,yuvraj,196,7,9')
pd.read_csv(StringIO(data),index_col = ['MyIndex'])
# Out:
#           Columns1  Column2  columns3 column4
# MyIndex
# 11            tony      100         4       p
# 22       vednesday      200         6     NaN
# 33          yuvraj      196         7       9
