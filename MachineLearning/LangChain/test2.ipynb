# %%
print("HI")
# Out:
# HI

# %%
import pandas as pd
df = pd.read_csv("/Users/yuvrajbhatkariya/Downloads/review.csv")
print(df.shape)
print(df.label.value_counts())
df.sample(5)
# Out:
# (147688, 4)
# label
# good    109309
# poor     29834
# ok        8545
# Name: count, dtype: int64
#                                Brand Name  Rating  \
# 59713                               apple       5
# 15496  New Apple iPhone 11 (64GB) - Black       5
# 87        Apple iPhone 11 (128GB) - White       5
# 1186      Apple iPhone 11 (128GB) - White       4
# 76028                               apple       5
#
#                                                  Reviews label
# 59713                                               Nice  good
# 15496                                   Iphone is better  good
# 87                                             Wonderful  good
# 1186             Camera quality is good and size is good  good
# 76028  the fhone looks ,and works perfect in argentia...  good

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.shape(5)
#
# TypeError: 'tuple' object is not callable
