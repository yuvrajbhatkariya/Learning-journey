# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os

# Load .env
load_dotenv()

# Configure API
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))

# Print available models
for model in genai.list_models():
    print(model.name)

# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os

load_dotenv()

API_KEY = os.getenv("GOOGLE_API_KEY")

genai.configure(api_key=API_KEY)

model = genai.GenerativeModel("models/gemini-2.5-flash-lite")

response = model.generate_content("What is AI?")

print(response.text)

# %%
from langchain_huggingface import ChatHuggingFace ,HuggingFaceEndpoint
from dotenv import load_dotenv
import os

load_dotenv()

# print(os.getenv("HUGGINGFACEHUB_API_TOKEN"))  # test

# %%
from langchain_huggingface import HuggingFaceEndpoint
from dotenv import load_dotenv

load_dotenv()

llm = HuggingFaceEndpoint(
    repo_id="openai-community/openai-gpt",   # small free model
    task="text-generation"
)

result = llm.invoke("How many players are in a football team?")
print(result)

# %%
llm = HuggingFaceEndpoint(
    repo_id="mistralai/Mistral-7B-Instruct-v0.2",
    task= 'text-generation',
    temperature = 0.5,
    max_new_tokens = 100
)
model = ChatHuggingFace(llm=llm)

# %%
# llm = HuggingFaceEndpoint(
#     repo_id='HuggingFaceH4/zephyr-7b-beta',
#     task='text-generation',
#     max_new_tokens=200,
#     temperature=0.2
# )
# model = ChatHuggingFace(llm=llm)

# %%
from langchain_core.messages import HumanMessage

result = model.invoke([
    HumanMessage(content="How many players are in a football team?")
])

print(result.content)

# %%
from langchain_huggingface import HuggingFaceEndpoint

llm = HuggingFaceEndpoint(
    repo_id="google/gemma-2b",
    task="text-generation",
    temperature=0.7
)

result = llm.invoke("How many players are in a football team?")
print(result)

# %%
print("hi")

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

result = generator("AI is", max_length=50)

print(result)
